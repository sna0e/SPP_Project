# %% [markdown]
# # 라이브러리 import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 데이터 확인

# %% [markdown]
# - 10~15 : 4차
# - 16~20 : COVID 이전
# - 21~22 : COVID
# <br>
# 평균 내기

# %% [markdown]
# ## employment_rate 어린 친구들 취업

# %%
employment_rate = pd.read_csv("Employment rate by age group.csv", index_col="LOCATION")

# %%
employment_rate
# Out:
#          INDICATOR SUBJECT MEASURE FREQUENCY    TIME     Value Flag Codes
# LOCATION
# AUS         EMPAGE   25_54  PC_AGE         A    1979  70.71983        NaN
# AUS         EMPAGE   25_54  PC_AGE         A    1980  71.19049        NaN
# AUS         EMPAGE   25_54  PC_AGE         A    1981  71.39142        NaN
# AUS         EMPAGE   25_54  PC_AGE         A    1982  70.63979        NaN
# AUS         EMPAGE   25_54  PC_AGE         A    1983  68.88377        NaN
# ...            ...     ...     ...       ...     ...       ...        ...
# CRI         EMPAGE   15_24  PC_AGE         M  Dec-22  29.22098        NaN
# CRI         EMPAGE   15_24  PC_AGE         M  Jan-23  29.41770        NaN
# CRI         EMPAGE   15_24  PC_AGE         M  Feb-23  29.00468        NaN
# CRI         EMPAGE   15_24  PC_AGE         M  Mar-23  28.86939        NaN
# CRI         EMPAGE   15_24  PC_AGE         M  Apr-23  28.69330        NaN
#
# [25745 rows x 7 columns]

# %%
set(employment_rate[employment_rate["SUBJECT"] == "15_24"]["TIME"])
# Out:
# {'1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1970-Q1',
#  '1970-Q2',
#  '1970-Q3',
#  '1970-Q4',
#  '1971',
#  '1971-Q1',
#  '1971-Q2',
#  '1971-Q3',
#  '1971-Q4',
#  '1972',
#  '1972-Q1',
#  '1972-Q2',
#  '1972-Q3',
#  '1972-Q4',
#  '1973',
#  '1973-Q1',
#  '1973-Q2',
#  '1973-Q3',
#  '1973-Q4',
#  '1974',
#  '1974-Q1',
#  '1974-Q2',
#  '1974-Q3',
#  '1974-Q4',
#  '1975',
#  '1975-Q1',
#  '1975-Q2',
#  '1975-Q3',
#  '1975-Q4',
#  '1976',
#  '1976-Q1',
#  '1976-Q2',
#  '1976-Q3',
#  '1976-Q4',
#  '1977',
#  '1977-Q1',
#  '1977-Q2',
#  '1977-Q3',
#  '1977-Q4',
#  '1978',
#  '1978-Q1',
#  '1978-Q2',
#  '1978-Q3',
#  '1978-Q4',
#  '1979',
#  '1979-Q1',
#  '1979-Q2',
#  '1979-Q3',
#  '1979-Q4',
#  '1980',
#  '1980-Q1',
#  '1980-Q2',
#  '1980-Q3',
#  '1980-Q4',
#  '1981',
#  '1981-Q1',
#  '1981-Q2',
#  '1981-Q3',
#  '1981-Q4',
#  '1982',
#  '1982-Q1',
# ...

# %%
employment_rate_1524 = employment_rate[employment_rate["SUBJECT"] == "15_24"]

# %%
employment_rate_1524_2020 = employment_rate_1524[employment_rate_1524["TIME"] == "2020"]
employment_rate_1524_2020
# Out:
#           INDICATOR SUBJECT MEASURE FREQUENCY  TIME      Value Flag Codes
# LOCATION
# AUT          EMPAGE   15_24  PC_AGE         A  2020  49.775000        NaN
# BEL          EMPAGE   15_24  PC_AGE         A  2020  23.875000        NaN
# CAN          EMPAGE   15_24  PC_AGE         A  2020  49.683330        NaN
# CZE          EMPAGE   15_24  PC_AGE         A  2020  25.125000        NaN
# DNK          EMPAGE   15_24  PC_AGE         A  2020  53.225000        NaN
# FIN          EMPAGE   15_24  PC_AGE         A  2020  40.950000        NaN
# FRA          EMPAGE   15_24  PC_AGE         A  2020  28.900000        NaN
# DEU          EMPAGE   15_24  PC_AGE         A  2020  48.320100          E
# GRC          EMPAGE   15_24  PC_AGE         A  2020  13.025000        NaN
# HUN          EMPAGE   15_24  PC_AGE         A  2020  27.950000        NaN
# ISL          EMPAGE   15_24  PC_AGE         A  2020  65.500000          B
# IRL          EMPAGE   15_24  PC_AGE         A  2020  35.875000        NaN
# ...

# %% [markdown]
# ## 어린 친구들 취업2 - 조금 더 세부적인 나이 구분 가능 - 1 이용하는 거로

# %%
employment_rate_2 = pd.read_csv("early employment rate.csv")

# %%
employment_rate_2
# Out:
#       COUNTRY    Country    SEX          Sex   AGE       Age SERIES  \
# 0         AUS  Australia     MW  All persons  1519  15 to 19  PER_E
# 1         AUS  Australia     MW  All persons  1519  15 to 19  PER_E
# 2         AUS  Australia     MW  All persons  1519  15 to 19  PER_E
# 3         AUS  Australia     MW  All persons  1519  15 to 19  PER_E
# 4         AUS  Australia     MW  All persons  1519  15 to 19  PER_E
# ...       ...        ...    ...          ...   ...       ...    ...
# 78874     SVN   Slovenia  WOMEN        Women  7074  70 to 74  PER_U
# 78875     NOR     Norway  WOMEN        Women  8099       80+  PER_E
# 78876     DNK    Denmark     MW  All persons  8099       80+  PER_E
# 78877     NOR     Norway  WOMEN        Women  8099       80+  PER_L
# 78878     DNK    Denmark  WOMEN        Women  8099       80+  PER_L
#
#                       Series FREQUENCY Frequency  TIME  Time     Value  \
# 0        Share of employment         A    Annual  2010  2010  6.157369
# ...

# %%
employment_rate_2[employment_rate_2["TIME"] == 2020]
# Out:
#       COUNTRY    Country    SEX          Sex   AGE       Age SERIES  \
# 10        AUS  Australia     MW  All persons  1519  15 to 19  PER_E
# 23        AUS  Australia    MEN          Men  1519  15 to 19  PER_E
# 36        AUS  Australia  WOMEN        Women  1519  15 to 19  PER_E
# 49        AUS  Australia     MW  All persons  1519  15 to 19  PER_L
# 62        AUS  Australia    MEN          Men  1519  15 to 19  PER_L
# ...       ...        ...    ...          ...   ...       ...    ...
# 78818     COL   Colombia    MEN          Men  8099       80+  PER_P
# 78831     COL   Colombia  WOMEN        Women  8099       80+  PER_P
# 78844     COL   Colombia     MW  All persons  8099       80+  PER_U
# 78857     COL   Colombia    MEN          Men  8099       80+  PER_U
# 78869     COL   Colombia  WOMEN        Women  8099       80+  PER_U
#
#                       Series FREQUENCY Frequency  TIME  Time     Value  \
# 10       Share of employment         A    Annual  2020  2020  4.971046
# ...

# %% [markdown]
# ## 인구 수

# %%
population = pd.read_csv("population.csv")

# %%
population
# 단위 million
# Out:
#       LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME        Value  \
# 0          AUS       POP     MEN  MLN_PER         A  1950       4.1229
# 1          AUS       POP     MEN  MLN_PER         A  1951       4.2537
# 2          AUS       POP     MEN  MLN_PER         A  1952       4.3726
# 3          AUS       POP     MEN  MLN_PER         A  1953       4.4626
# 4          AUS       POP     MEN  MLN_PER         A  1954       4.5461
# ...        ...       ...     ...      ...       ...   ...          ...
# 12085     EU27       POP   WOMEN  MLN_PER         A  2017  228089.5515
# 12086     EU27       POP   WOMEN  MLN_PER         A  2018  228397.5095
# 12087     EU27       POP   WOMEN  MLN_PER         A  2019  228791.6280
# 12088     EU27       POP   WOMEN  MLN_PER         A  2020  228954.0395
# 12089     EU27       POP   WOMEN  MLN_PER         A  2021  228632.3950
#
#        Flag Codes
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# ...

# %%
population = population[population["SUBJECT"] == "TOT"]
population_2020 = population[population["TIME"] == 2020]
population_2020
# Out:
#       LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME        Value  \
# 142        AUS       POP     TOT  MLN_PER         A  2020    25.693267
# 358        AUT       POP     TOT  MLN_PER         A  2020     8.916845
# 574        BEL       POP     TOT  MLN_PER         A  2020    11.506938
# 790        CAN       POP     TOT  MLN_PER         A  2020    38.037204
# 1006       CZE       POP     TOT  MLN_PER         A  2020    10.700155
# 1222       DNK       POP     TOT  MLN_PER         A  2020     5.825337
# 1438       FIN       POP     TOT  MLN_PER         A  2020     5.529545
# 1654       FRA       POP     TOT  MLN_PER         A  2020    67.540257
# 1870       DEU       POP     TOT  MLN_PER         A  2020    83.160874
# 2086       GRC       POP     TOT  MLN_PER         A  2020    10.698597
# 2302       HUN       POP     TOT  MLN_PER         A  2020     9.750153
# 2518       ISL       POP     TOT  MLN_PER         A  2020     0.366462
# ...

# %% [markdown]
# ## employment X 인구 수 join - 안해도 됨

# %%
#empolyment_population = pd.merge(employment_rate_1524_2021, population_2021, on="LOCATION")

# %%
#empolment_population["Value_y"] = empolment_population["Value_y"] * 1000000

# %% [markdown]
# ## 사교육비

# %%
private_education = pd.read_csv("사교육비.csv", index_col="LOCATION")

# %%
set(private_education["TIME"])
# Out:
# {1995,
#  2000,
#  2005,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020}

# %%
private_education[private_education["TIME"] == 2020]
# Out:
#            INDICATOR   SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# LOCATION
# NZL       EDUPRIVEXP       PRY  PC_GDP         A  2020  0.076396         NaN
# NZL       EDUPRIVEXP       TRY  PC_GDP         A  2020  0.689730         NaN
# NZL       EDUPRIVEXP  PRY_NTRY  PC_GDP         A  2020  0.367073         NaN
# NZL       EDUPRIVEXP   PRY_TRY  PC_GDP         A  2020  1.056803         NaN
# NZL       EDUPRIVEXP       SRY  PC_GDP         A  2020  0.253776         NaN

# %% [markdown]
# # 전처리

# %% [markdown]
# ## 10-15 / 16-20 다 나눠서 저장하기

# %% [markdown]
# ### 취업률

# %%
year_list_1015 = np.array(range(2010, 2016))
year_list_1620 = np.array(range(2016, 2021))

# %%
employment_rate_1015year = pd.DataFrame()
employment_rate_1620year = pd.DataFrame()

# %%
er10 = employment_rate_1524[employment_rate_1524["TIME"] == "2010"]
er11 = employment_rate_1524[employment_rate_1524["TIME"] == "2011"]
er12 = employment_rate_1524[employment_rate_1524["TIME"] == "2012"]
er13 = employment_rate_1524[employment_rate_1524["TIME"] == "2013"]
er14 = employment_rate_1524[employment_rate_1524["TIME"] == "2014"]
er15 = employment_rate_1524[employment_rate_1524["TIME"] == "2015"]
er16 = employment_rate_1524[employment_rate_1524["TIME"] == "2016"]
er17 = employment_rate_1524[employment_rate_1524["TIME"] == "2017"]
er18 = employment_rate_1524[employment_rate_1524["TIME"] == "2018"]
er19 = employment_rate_1524[employment_rate_1524["TIME"] == "2019"]
er20 = employment_rate_1524[employment_rate_1524["TIME"] == "2020"]

# %%
print(len(list(er10.Value)))
print(len(list(er11.Value)))
print(len(list(er12.Value)))
print(len(list(er13.Value)))
print(len(list(er14.Value)))
print(len(list(er15.Value)))
print(len(list(er16.Value)))
print(len(list(er17.Value)))
print(len(list(er18.Value)))
print(len(list(er19.Value)))
print(len(list(er20.Value)))
# Out:
# 43
# 45
# 45
# 45
# 45
# 44
# 44
# 44
# 44
# 44
# 43

# %%
df_list = [er10.Value, er11.Value, er12.Value, er13.Value, er14.Value, er15.Value]

employment_rate_1015year = pd.concat(df_list, ignore_index=True, axis=1)

# %%
employment_rate_1015year.columns = range(2010, 2016)

# %%
employment_rate_1015year
# Out:
#                2010      2011      2012      2013      2014      2015
# AUT        52.75000  53.90000  53.67500  53.07500  52.05000  51.37500
# BEL        25.22500  26.00000  25.25000  23.62500  23.20000  23.35000
# CAN        56.00834  56.46667  55.90000  56.65000  56.73333  57.13334
# CZE        25.22500  24.50000  25.20000  25.55000  27.10000  28.37500
# DNK        54.00000  53.00000  51.37500  49.52500  49.97500  51.35000
# FIN        38.17500  39.80000  41.12500  40.90000  41.20000  39.97500
# FRA        30.05000  29.55000  28.52500  28.35000  28.10000  28.45000
# DEU        45.62500  47.30000  46.00000  46.27500  45.42500  44.70000
# GRC        20.35000  16.30000  13.00000  11.85000  13.55000  13.42500
# HUN        18.77500  18.50000  18.82500  20.60000  23.97500  26.07500
# ISL        61.72500  62.50000  65.40000  69.70000  70.50000  73.10000
# IRL        38.72500  36.17500  34.80000  36.52500  36.77500  37.77500
# ...

# %%
employment_rate_1015year["employment_rate_1015"] = employment_rate_1015year.sum(axis=1) / 6
employment_rate_1015year
# Out:
#                2010      2011      2012      2013      2014      2015  \
# AUT        52.75000  53.90000  53.67500  53.07500  52.05000  51.37500
# BEL        25.22500  26.00000  25.25000  23.62500  23.20000  23.35000
# CAN        56.00834  56.46667  55.90000  56.65000  56.73333  57.13334
# CZE        25.22500  24.50000  25.20000  25.55000  27.10000  28.37500
# DNK        54.00000  53.00000  51.37500  49.52500  49.97500  51.35000
# FIN        38.17500  39.80000  41.12500  40.90000  41.20000  39.97500
# FRA        30.05000  29.55000  28.52500  28.35000  28.10000  28.45000
# DEU        45.62500  47.30000  46.00000  46.27500  45.42500  44.70000
# GRC        20.35000  16.30000  13.00000  11.85000  13.55000  13.42500
# HUN        18.77500  18.50000  18.82500  20.60000  23.97500  26.07500
# ISL        61.72500  62.50000  65.40000  69.70000  70.50000  73.10000
# IRL        38.72500  36.17500  34.80000  36.52500  36.77500  37.77500
# ...

# %%
df_list = [er16.Value, er17.Value, er18.Value, er19.Value, er20.Value]
employment_rate_1620year = pd.concat(df_list, ignore_index=True, axis=1)
employment_rate_1620year.columns = range(2016, 2021)
employment_rate_1620year["employment_rate_1620"] = employment_rate_1620year.sum(axis=1) / 5
employment_rate_1620year
# Out:
#                2016      2017      2018      2019       2020  \
# AUT        51.00000  50.57500  51.35000  51.62500  49.775000
# BEL        22.75000  22.70000  24.97500  26.57500  23.875000
# CAN        56.60000  57.95000  57.90000  58.69167  49.683330
# CZE        28.62500  29.15000  28.37500  28.05000  25.125000
# DNK        52.30000  52.90000  53.75000  55.00000  53.225000
# FIN        41.27500  42.47500  43.60000  44.15000  40.950000
# FRA        28.40000  29.17500  30.22500  30.10000  28.900000
# DEU        45.17500  45.87500  46.52500  47.82500  48.320100
# GRC        13.20000  14.47500  14.30000  14.82500  13.025000
# HUN        28.67500  29.65000  29.95000  29.07500  27.950000
# ISL        77.60000  75.77500  75.40000  71.65000  65.500000
# IRL        41.97500  39.92500  40.22500  41.17500  35.875000
# ITA        16.52500  17.07500  17.57500  18.37500  16.625000
# JPN        42.11147  42.38587  45.70039  47.12876  46.065010
# ...

# %%
employment_rate_1015year.to_csv("./done_prepro/employment_rate_1015year.csv")
employment_rate_1620year.to_csv("./done_prepro/employment_rate_1620year.csv")

# %% [markdown]
# ### 사교육비

# %%
private_education
# Out:
#            INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# LOCATION
# AUS       EDUPRIVEXP     PRY  PC_GDP         A  2000  0.190555         NaN
# AUS       EDUPRIVEXP     PRY  PC_GDP         A  2005  0.183107         NaN
# AUS       EDUPRIVEXP     PRY  PC_GDP         A  2008  0.192965         NaN
# AUS       EDUPRIVEXP     PRY  PC_GDP         A  2009  0.195736         NaN
# AUS       EDUPRIVEXP     PRY  PC_GDP         A  2010  0.200202         NaN
# ...              ...     ...     ...       ...   ...       ...         ...
# OAVG      EDUPRIVEXP     SRY  PC_GDP         A  2015  0.215472         NaN
# OAVG      EDUPRIVEXP     SRY  PC_GDP         A  2016  0.226189         NaN
# OAVG      EDUPRIVEXP     SRY  PC_GDP         A  2017  0.217287         NaN
# OAVG      EDUPRIVEXP     SRY  PC_GDP         A  2018  0.220876         NaN
# OAVG      EDUPRIVEXP     SRY  PC_GDP         A  2019  0.212349         NaN
#
# [2629 rows x 7 columns]

# %%
private_edu_1015year = pd.DataFrame()
private_edu_1620year = pd.DataFrame()

# %%
er10 = private_education[private_education["TIME"] == 2010]
er11 = private_education[private_education["TIME"] == 2011]
er12 = private_education[private_education["TIME"] == 2012]
er13 = private_education[private_education["TIME"] == 2013]
er14 = private_education[private_education["TIME"] == 2014]
er15 = private_education[private_education["TIME"] == 2015]
er16 = private_education[private_education["TIME"] == 2016]
er17 = private_education[private_education["TIME"] == 2017]
er18 = private_education[private_education["TIME"] == 2018]
er19 = private_education[private_education["TIME"] == 2019]
er20 = private_education[private_education["TIME"] == 2020]

# %%
er10
# Out:
#            INDICATOR        SUBJECT MEASURE FREQUENCY  TIME     Value  \
# LOCATION
# AUS       EDUPRIVEXP            PRY  PC_GDP         A  2010  0.200202
# AUS       EDUPRIVEXP            TRY  PC_GDP         A  2010  0.897257
# BEL       EDUPRIVEXP            TRY  PC_GDP         A  2010  0.135787
# CAN       EDUPRIVEXP            PRY  PC_GDP         A  2010  0.407698
# CAN       EDUPRIVEXP            TRY  PC_GDP         A  2010  1.172812
# ...              ...            ...     ...       ...   ...       ...
# LTU       EDUPRIVEXP            SRY  PC_GDP         A  2010  0.056378
# RUS       EDUPRIVEXP  EARLYCHILDEDU  PC_GDP         A  2010  0.000000
# RUS       EDUPRIVEXP            SRY  PC_GDP         A  2010  0.016525
# SVN       EDUPRIVEXP            SRY  PC_GDP         A  2010  0.185321
# OAVG      EDUPRIVEXP            PRY  PC_GDP         A  2010  0.132518
#
#           Flag Codes
# LOCATION
# AUS              NaN
# AUS              NaN
# BEL              NaN
# ...

# %%
er10 = er10[er10["SUBJECT"] == "TRY"]
er11 = er11[er11["SUBJECT"] == "TRY"]
er12 = er12[er12["SUBJECT"] == "TRY"]
er13 = er13[er13["SUBJECT"] == "TRY"]
er14 = er14[er14["SUBJECT"] == "TRY"]
er15 = er15[er15["SUBJECT"] == "TRY"]
er16 = er16[er16["SUBJECT"] == "TRY"]
er17 = er17[er17["SUBJECT"] == "TRY"]
er18 = er18[er18["SUBJECT"] == "TRY"]
er19 = er19[er19["SUBJECT"] == "TRY"]
er20 = er20[er20["SUBJECT"] == "TRY"]

# %%
er17
# Out:
#            INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# LOCATION
# AUS       EDUPRIVEXP     TRY  PC_GDP         A  2017  1.287018         NaN
# AUT       EDUPRIVEXP     TRY  PC_GDP         A  2017  0.152499         NaN
# BEL       EDUPRIVEXP     TRY  PC_GDP         A  2017  0.211221         NaN
# CAN       EDUPRIVEXP     TRY  PC_GDP         A  2017  1.065671         NaN
# CZE       EDUPRIVEXP     TRY  PC_GDP         A  2017  0.215420         NaN
# DNK       EDUPRIVEXP     TRY  PC_GDP         A  2017  0.171217         NaN
# FIN       EDUPRIVEXP     TRY  PC_GDP         A  2017  0.054793         NaN
# FRA       EDUPRIVEXP     TRY  PC_GDP         A  2017  0.307356         NaN
# DEU       EDUPRIVEXP     TRY  PC_GDP         A  2017  0.184552         NaN
# ISL       EDUPRIVEXP     TRY  PC_GDP         A  2017  0.101385         NaN
# IRL       EDUPRIVEXP     TRY  PC_GDP         A  2017  0.265418         NaN
# ...

# %%
df_list_1015 = [er10.Value, er11.Value, er12.Value, er13.Value, er14.Value, er15.Value]
df_list_1620 = [er16.Value, er17.Value, er18.Value, er19.Value, er20.Value]

private_edu_1015year = pd.concat(df_list_1015, ignore_index=True, axis=1)
private_edu_1015year.columns = range(2010, 2016)
private_edu_1015year["private_edu_1015"] = private_edu_1015year.mean(axis=1)
private_edu_1015year

private_edu_1620year = pd.concat(df_list_1620, ignore_index=True, axis=1)
private_edu_1620year.columns = range(2016, 2021)
private_edu_1620year["private_edu_1620"] = private_edu_1620year.mean(axis=1)
private_edu_1620year
# Out:
#           2016      2017      2018      2019     2020  private_edu_1620
# AUS   1.157478  1.287018  1.230655  1.274721      NaN          1.237468
# AUT   0.112024  0.152499  0.182838  0.192576      NaN          0.159984
# BEL   0.214842  0.211221  0.201010  0.190233      NaN          0.204327
# CAN   1.096771  1.065671  1.108996  1.010782      NaN          1.070555
# CZE   0.222914  0.215420  0.208251  0.200030      NaN          0.211654
# DNK   0.158147  0.171217  0.188281  0.192793      NaN          0.177609
# FIN   0.056618  0.054793  0.058035  0.063285      NaN          0.058183
# FRA   0.307323  0.307356  0.318453  0.333664      NaN          0.316699
# DEU   0.188189  0.184552  0.183606  0.215859      NaN          0.193052
# ISL   0.100777  0.101385  0.099061  0.096310      NaN          0.099383
# IRL   0.285412  0.265418  0.241920  0.221871      NaN          0.253655
# ITA   0.319951  0.315529  0.323651  0.331045      NaN          0.322544
# ...

# %%
private_edu_1015year.to_csv("./done_prepro/private_edu_1015year.csv")
private_edu_1620year.to_csv("./done_prepro/private_edu_1620year.csv")

# %% [markdown]
# ### 첫 결혼 나이

# %% [markdown]
# ### 행복지수

# %%
happiness_origin = pd.read_csv("happiness.csv")
happiness_origin
# Out:
#      Unnamed: 0 Country name  year  Life Ladder  Log GDP per capita  \
# 0             0          AUS  2005        7.341              10.662
# 1             1          AUS  2007        7.285              10.694
# 2             2          AUS  2008        7.254              10.709
# 3             3          AUS  2010        7.450              10.714
# 4             4          AUS  2011        7.406              10.723
# ..          ...          ...   ...          ...                 ...
# 512         512          USA  2018        6.883              11.024
# 513         513          USA  2019        6.944              11.043
# 514         514          USA  2020        7.028              11.005
# 515         515          USA  2021        6.959              11.061
# 516         516          USA  2022        6.693              11.079
#
#      Social support  Healthy life expectancy at birth  \
# 0             0.968                            69.800
# ...

# %%
happiness = pd.DataFrame()
happiness["LOCATION"] = happiness_origin["Country name"]
happiness["TIME"] = happiness_origin["year"]
happiness["Value"] = happiness_origin["Life Ladder"]
happiness.index = happiness["LOCATION"]

# %%
happiness
# Out:
#          LOCATION  TIME  Value
# LOCATION
# AUS           AUS  2005  7.341
# AUS           AUS  2007  7.285
# AUS           AUS  2008  7.254
# AUS           AUS  2010  7.450
# AUS           AUS  2011  7.406
# ...           ...   ...    ...
# USA           USA  2018  6.883
# USA           USA  2019  6.944
# USA           USA  2020  7.028
# USA           USA  2021  6.959
# USA           USA  2022  6.693
#
# [517 rows x 3 columns]

# %%
er10 = happiness[happiness["TIME"] == 2010]
er11 = happiness[happiness["TIME"] == 2011]
er12 = happiness[happiness["TIME"] == 2012]
er13 = happiness[happiness["TIME"] == 2013]
er14 = happiness[happiness["TIME"] == 2014]
er15 = happiness[happiness["TIME"] == 2015]
er16 = happiness[happiness["TIME"] == 2016]
er17 = happiness[happiness["TIME"] == 2017]
er18 = happiness[happiness["TIME"] == 2018]
er19 = happiness[happiness["TIME"] == 2019]
er20 = happiness[happiness["TIME"] == 2020]

# %%
er10
# Out:
#          LOCATION  TIME  Value
# LOCATION
# AUS           AUS  2010  7.450
# AUT           AUT  2010  7.303
# BEL           BEL  2010  6.854
# CAN           CAN  2010  7.650
# CHL           CHL  2010  6.636
# DNK           DNK  2010  7.771
# FIN           FIN  2010  7.393
# FRA           FRA  2010  6.798
# DEU           DEU  2010  6.725
# GRC           GRC  2010  5.840
# HUN           HUN  2010  4.725
# IRL           IRL  2010  7.257
# ISR           ISR  2010  7.359
# ITA           ITA  2010  6.354
# JPN           JPN  2010  6.057
# LTU           LTU  2010  5.066
# LUX           LUX  2010  7.097
# MEX           MEX  2010  6.802
# NLD           NLD  2010  7.502
# NZL           NZL  2010  7.224
# POL           POL  2010  5.887
# PRT           PRT  2010  5.095
# SVK           SVK  2010  6.052
# SVN           SVN  2010  6.083
# ESP           ESP  2010  6.188
# SWE           SWE  2010  7.496
# GBR           GBR  2010  7.029
# USA           USA  2010  7.164

# %%
df_list_1015 = [er10.Value, er11.Value, er12.Value, er13.Value, er14.Value, er15.Value]
df_list_1620 = [er16.Value, er17.Value, er18.Value, er19.Value, er20.Value]

happiness_1015year = pd.concat(df_list_1015, ignore_index=True, axis=1)
happiness_1015year.columns = range(2010, 2016)
happiness_1015year["happiness_1015"] = happiness_1015year.mean(axis=1)
happiness_1015year
# Out:
#       2010   2011   2012   2013   2014   2015  happiness_1015
# AUS  7.450  7.406  7.196  7.364  7.289  7.309        7.335667
# AUT  7.303  7.471  7.401  7.499  6.950  7.076        7.283333
# BEL  6.854  7.111  6.935  7.104  6.855  6.904        6.960500
# CAN  7.650  7.426  7.415  7.594  7.304  7.413        7.467000
# CHL  6.636  6.526  6.599  6.740  6.844  6.533        6.646333
# DNK  7.771  7.788  7.520  7.589  7.508  7.514        7.615000
# FIN  7.393  7.354  7.420  7.445  7.385  7.448        7.407500
# FRA  6.798  6.959  6.649  6.667  6.467  6.358        6.649667
# DEU  6.725  6.621  6.702  6.965  6.984  7.037        6.839000
# GRC  5.840  5.372  5.096  4.720  4.756  5.623        5.234500
# HUN  4.725  4.918  4.683  4.914  5.181  5.344        4.960833
# IRL  7.257  7.007  6.965  6.760  7.018  6.830        6.972833
# ISR  7.359  7.433  7.111  7.321  7.401  7.079        7.284000
# ITA  6.354  6.057  5.839  6.009  6.027  5.848        6.022333
# ...

# %%
happiness_1620year = pd.concat(df_list_1620, ignore_index=True, axis=1)
happiness_1620year.columns = range(2016, 2021)
happiness_1620year["happiness_1620"] = happiness_1620year.mean(axis=1)
happiness_1620year
# Out:
#       2016   2017   2018   2019   2020  happiness_1620
# AUS  7.250  7.257  7.177  7.234  7.137         7.21100
# AUT  7.048  7.294  7.396  7.195  7.213         7.22920
# BEL  6.949  6.928  6.892  6.772  6.839         6.87600
# CAN  7.245  7.415  7.175  7.109  7.025         7.19380
# CHL  6.579  6.320  6.436  5.942  6.151         6.28560
# DNK  7.558  7.594  7.649  7.693  7.515         7.60180
# EST  5.650  5.938  6.091  6.035  6.453         6.03340
# FIN  7.660  7.788  7.858  7.780  7.889         7.79500
# FRA  6.475  6.635  6.666  6.690  6.714         6.63600
# DEU  6.874  7.074  7.118  7.035  7.312         7.08260
# GRC  5.303  5.148  5.409  5.952  5.788         5.52000
# HUN  5.449  6.065  5.936  6.000  6.038         5.89760
# ISL  7.510  7.476    NaN  7.533  7.575         7.52350
# IRL  7.041  7.060  6.962  7.255  7.035         7.07060
# ISR  7.159  7.331  6.927  7.332  7.195         7.18880
# ITA  5.955  6.199  6.517  6.445  6.488         6.32080
# ...

# %%
happiness_1015year.to_csv("./done_prepro/happiness_1015year.csv")
happiness_1620year.to_csv("./done_prepro/happiness_1620year.csv")

# %% [markdown]
# ### 데이터 연대별로 합친 테이블

# %%
# 취업
er_1015 = pd.read_csv("./done_prepro/employment_rate_1015year.csv")
er_1620 = pd.read_csv("./done_prepro/employment_rate_1620year.csv")
# 사교육
pe_1015 = pd.read_csv("./done_prepro/private_edu_1015year.csv")
pe_1620 = pd.read_csv("./done_prepro/private_edu_1620year.csv")
# 가구 형태
ns_total = pd.read_csv("./done_prepro/living_with_parent_percentage.csv")
# 결혼 나이
ma_total = pd.read_csv("./done_prepro/marriage_average.csv")
# 행복 지수
h_1015 = pd.read_csv("./done_prepro/happiness_1015year.csv")
h_1620 = pd.read_csv("./done_prepro/happiness_1620year.csv")

# %%
df_1015_merge = pd.DataFrame()

# %% [markdown]
# ### 10-15s

# %%
print(len(pe_1015))
print(len(er_1015))
# Out:
# 40
# 45

# %%
country_list_1015 =er_1015.iloc[:, 0].append(pe_1015.iloc[:, 0], ignore_index=True) 
print(len(country_list_1015))
# Out:
# 85

# %%
country_list_1015 = set(country_list_1015)
len(country_list_1015)
# Out:
# 47

# %%
df_1015_merge["LOCATION"] = list(country_list_1015)

df_1015_merge = pd.merge(df_1015_merge, er_1015, how="left", on="LOCATION")
df_1015_merge = pd.merge(df_1015_merge, pe_1015, how="left", on="LOCATION")
df_1015_merge = pd.merge(df_1015_merge, ma_total, how="left", on="LOCATION")
df_1015_merge = pd.merge(df_1015_merge, h_1015, how="left", on="LOCATION")
df_1015_merge = pd.merge(df_1015_merge, ns_total, how="left", on="LOCATION")

# %%
df_1015_merge
# Out:
#      LOCATION    2010_x    2011_x    2012_x    2013_x    2014_x    2015_x  \
# 0         DEU  45.62500  47.30000  46.00000  46.27500  45.42500  44.70000
# 1         G-7  42.15007  42.40685  42.30742  42.59966  43.22036  43.85122
# 2         ESP  24.97500  22.00000  18.40000  16.82500  16.70000  17.92500
# 3         NOR  51.45000  50.82500  52.20000  51.80000  50.15000  50.37500
# 4         SWE  39.37500  41.57500  40.82500  42.37500  43.45000  44.57500
# 5         NZL  49.21640  49.00301  48.45407  49.02097  51.59349  52.91188
# 6         DNK  54.00000  53.00000  51.37500  49.52500  49.97500  51.35000
# 7         ITA  20.17500  19.17500  18.45000  16.27500  15.55000  15.60000
# 8         FIN  38.17500  39.80000  41.12500  40.90000  41.20000  39.97500
# 9         NLD  68.67500  69.25000  69.02500  67.92500  66.60000  68.57500
# 10       EA19  33.40000  33.07500  31.75000  31.12500  30.85000  31.12500
# 11  EU27_2020  31.65000  31.22500  30.27500  29.80000  29.92500  30.37500
# ...

# %%
df_1015 = pd.DataFrame()

# %%
df_1015["LOCATION"] = df_1015_merge["LOCATION"] 
df_1015["employment_rate_1015"] = df_1015_merge["employment_rate_1015"] 
df_1015["private_edu_1015"] = df_1015_merge["private_edu_1015"] 
df_1015["first_married_1015"] = df_1015_merge["married_1015"] 
df_1015["non_single_1015"] = df_1015_merge["non_single_1015"] 
df_1015["happiness_1015"] = df_1015_merge["happiness_1015"]

# %%
df_1015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 0 to 46
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   LOCATION              47 non-null     object
#  1   employment_rate_1015  45 non-null     float64
#  2   private_edu_1015      40 non-null     float64
#  3   first_married_1015    34 non-null     float64
#  4   non_single_1015       27 non-null     float64
#  5   happiness_1015        33 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 2.6+ KB

# %% [markdown]
# ### 16-20s

# %%
df_1620_merge = pd.DataFrame()

# %%
print(len(pe_1620))
print(len(er_1620))

country_list_1620 =er_1620.iloc[:, 0].append(pe_1620.iloc[:, 0], ignore_index=True) 
print(len(country_list_1620))

country_list_1620 = set(country_list_1620)
len(country_list_1620)
# Out:
# 38
# 44
# 82
# 45

# %%
df_1620_merge["LOCATION"] = list(country_list_1620)

df_1620_merge = pd.merge(df_1620_merge, er_1620, how="left", on="LOCATION")
df_1620_merge = pd.merge(df_1620_merge, pe_1620, how="left", on="LOCATION")
df_1620_merge = pd.merge(df_1620_merge, ma_total, how="left", on="LOCATION")
df_1620_merge = pd.merge(df_1620_merge, h_1620, how="left", on="LOCATION")
df_1620_merge = pd.merge(df_1620_merge, ns_total, how="left", on="LOCATION")

# %%
df_1620_merge
# Out:
#      LOCATION    2016_x    2017_x    2018_x    2019_x     2020_x  \
# 0         DEU  45.17500  45.87500  46.52500  47.82500  48.320100
# 1         G-7  44.60815  45.28210  46.02679  46.75819  43.213400
# 2         ESP  18.35000  20.47500  21.65000  22.27500  18.475000
# 3         NOR  48.47500  48.20000  49.07500  49.95000  49.325000
# 4         SWE  45.17500  45.60000  45.30000  44.55000  40.100000
# 5         NZL  53.98805  55.00819  56.19539  56.36789  55.079290
# 6         DNK  52.30000  52.90000  53.75000  55.00000  53.225000
# 7         ITA  16.52500  17.07500  17.57500  18.37500  16.625000
# 8         FIN  41.27500  42.47500  43.60000  44.15000  40.950000
# 9         NLD  68.55000  69.95000  71.55000  72.85000  69.975000
# 10       EA19  31.72500  32.65000  33.55000  34.17500  32.200000
# 11  EU27_2020  31.12500  32.17500  32.97500  33.52500  31.425000
# 12       OAVG       NaN       NaN       NaN       NaN        NaN
# ...

# %%
df_1620 = pd.DataFrame()
df_1620["LOCATION"] = df_1620_merge["LOCATION"] 
df_1620["employment_rate_1620"] = df_1620_merge["employment_rate_1620"] 
df_1620["private_edu_1620"] = df_1620_merge["private_edu_1620"] 
df_1620["first_married_1620"] = df_1620_merge["married_1620"] 
df_1620["non_single_1620"] = df_1620_merge["non_single_1620"] 
df_1620["happiness_1620"] = df_1620_merge["happiness_1620"]

# %%
df_1620
# Out:
#      LOCATION  employment_rate_1620  private_edu_1620  first_married_1620  \
# 0         DEU             46.744020          0.193052           32.525000
# 1         G-7             45.177726               NaN                 NaN
# 2         ESP             20.245000          0.415799           34.790000
# 3         NOR             49.005000          0.123113           33.730000
# 4         SWE             44.145000          0.183878           35.450000
# 5         NZL             55.327762          0.778063           29.820000
# 6         DNK             53.435000          0.177609           33.770000
# 7         ITA             17.235000          0.322544           33.960000
# 8         FIN             42.490000          0.058183           32.825000
# 9         NLD             70.575000          0.489562           32.820000
# 10       EA19             32.860000               NaN                 NaN
# 11  EU27_2020             32.245000               NaN                 NaN
# ...

# %%
df_1620.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 0 to 44
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   LOCATION              45 non-null     object
#  1   employment_rate_1620  44 non-null     float64
#  2   private_edu_1620      38 non-null     float64
#  3   first_married_1620    32 non-null     float64
#  4   non_single_1620       27 non-null     float64
#  5   happiness_1620        33 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 2.5+ KB

# %%
df_1015 = df_1015.dropna()
df_1620 = df_1620.dropna()

# %%
df_1015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 46
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   LOCATION              25 non-null     object
#  1   employment_rate_1015  25 non-null     float64
#  2   private_edu_1015      25 non-null     float64
#  3   first_married_1015    25 non-null     float64
#  4   non_single_1015       25 non-null     float64
#  5   happiness_1015        25 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.4+ KB

# %%
df_1620.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 0 to 44
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   LOCATION              24 non-null     object
#  1   employment_rate_1620  24 non-null     float64
#  2   private_edu_1620      24 non-null     float64
#  3   first_married_1620    24 non-null     float64
#  4   non_single_1620       24 non-null     float64
#  5   happiness_1620        24 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# # 정규화

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
# MinMaxScaler 로 데이터 셋 변환. fit() 과 transform() 호출.  
temp = df_1015.iloc[:, 1:]
scaler.fit(temp)
df_1015_scaled = scaler.transform(temp)

# transform()시 scale 변환된 데이터 셋이 numpy ndarry로 반환되어 이를 DataFrame으로 변환
df_1015_scaled = pd.DataFrame(data=df_1015_scaled)

# %%
df_1015_scaled.columns = ["employment_rate_1015", "private_edu_1015", "first_married_1015", "non_single_1015", "happiness_1015"]

# %%
df_1015_scaled
# Out:
#     employment_rate_1015  private_edu_1015  first_married_1015  \
# 0               0.581046          0.092086            0.626683
# 1               0.088160          0.202100            0.772338
# 2               0.678924          0.027977            0.751530
# 3               0.509057          0.090176            1.000000
# 4               0.686465          0.045299            0.771114
# 5               0.052087          0.179261            0.676255
# 6               0.474850          0.030353            0.594859
# 7               1.000000          0.278727            0.573072
# 8               0.411413          0.151402            0.685435
# 9               0.190857          0.166585            0.000000
# 10              0.710099          0.046767            0.600979
# 11              0.275597          0.240631            0.188494
# 12              0.262925          0.163993            0.728764
# 13              0.977843          0.050555            0.854345
# ...

# %% [markdown]
# # 상관분석

# %% [markdown]
# ### 10-15s

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.scatter("employment_rate_1015", "happiness_1015", data=df_1015)
plt.scatter("private_edu_1015", "happiness_1015", data=df_1015)
plt.scatter("first_married_1015", "happiness_1015", data=df_1015)
plt.scatter("non_single_1015", "happiness_1015", data=df_1015)
plt.scatter("happiness_1015", "happiness_1015", data=df_1015)

plt.show()

# %%
df_1015.corr()
# Out:
#                       employment_rate_1015  private_edu_1015  \
# employment_rate_1015              1.000000          0.215996
# private_edu_1015                  0.215996          1.000000
# first_married_1015                0.233309         -0.541688
# non_single_1015                  -0.654292         -0.023246
# happiness_1015                    0.755149         -0.003579
#
#                       first_married_1015  non_single_1015  happiness_1015
# employment_rate_1015            0.233309        -0.654292        0.755149
# private_edu_1015               -0.541688        -0.023246       -0.003579
# first_married_1015              1.000000        -0.419594        0.497171
# non_single_1015                -0.419594         1.000000       -0.784545
# happiness_1015                  0.497171        -0.784545        1.000000

# %%
sns.pairplot(df_1015, hue="happiness_1015")
# Out:
# C:\Users\claia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\claia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\claia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\claia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\claia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.heatmap(df_1015.corr(), annot=True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 16-20s

# %%
plt.scatter("employment_rate_1620", "happiness_1620", data=df_1620)
plt.scatter("private_edu_1620", "happiness_1620", data=df_1620)
plt.scatter("first_married_1620", "happiness_1620", data=df_1620)
plt.scatter("non_single_1620", "happiness_1620", data=df_1620)
plt.scatter("happiness_1620", "happiness_1620", data=df_1620)

plt.show()

# %%
df_1620.corr()
# Out:
#                       employment_rate_1620  private_edu_1620  \
# employment_rate_1620              1.000000          0.413157
# private_edu_1620                  0.413157          1.000000
# first_married_1620               -0.026612         -0.409970
# non_single_1620                  -0.687461         -0.078748
# happiness_1620                    0.724999          0.087252
#
#                       first_married_1620  non_single_1620  happiness_1620
# employment_rate_1620           -0.026612        -0.687461        0.724999
# private_edu_1620               -0.409970        -0.078748        0.087252
# first_married_1620              1.000000        -0.234785        0.389294
# non_single_1620                -0.234785         1.000000       -0.759773
# happiness_1620                  0.389294        -0.759773        1.000000

# %%
sns.pairplot(df_1620, hue="happiness_1620")
# Out:
# C:\Users\claia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\claia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\claia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\claia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\claia\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.heatmap(df_1620.corr(), annot=True, fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 회귀분석

# %%
from scipy import stats
from statsmodels.formula.api import ols, glm 
from statsmodels.graphics.regressionplots import plot_partregress_grid

# %% [markdown]
# ### 10-15s

# %%
model_1015 = ols ( 'happiness_1015~employment_rate_1015+private_edu_1015+first_married_1015+non_single_1015+happiness_1015', data=df_1015_scaled).fit()
model_1015.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         happiness_1015   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.710e+30
# Date:                Sun, 23 Jul 2023   Prob (F-statistic):          5.21e-281
# Time:                        09:39:41   Log-Likelihood:                 846.15
# No. Observations:                  25   AIC:                            -1680.
# Df Residuals:                      19   BIC:                            -1673.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
model_1015.params
# Out:
# Intercept              -4.272073e-15
# employment_rate_1015    1.781027e-17
# private_edu_1015       -2.704989e-16
# first_married_1015      1.826244e-16
# non_single_1015        -1.056567e-16
# happiness_1015          1.000000e+00
# dtype: float64

# %%
fig=plot_partregress_grid(model_1015)
fig.tight_layout(pad=1)

# %% [markdown]
# ### 16-20s

# %%
model_1620 = ols ( 'happiness_1620~employment_rate_1620+private_edu_1620+first_married_1620+non_single_1620+happiness_1620', data=df_1620).fit()
model_1620.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         happiness_1620   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.472e+28
# Date:                Sun, 23 Jul 2023   Prob (F-statistic):          7.27e-250
# Time:                        09:41:13   Log-Likelihood:                 746.11
# No. Observations:                  24   AIC:                            -1480.
# Df Residuals:                      18   BIC:                            -1473.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
model_1620.params
# Out:
# Intercept              -5.329071e-15
# employment_rate_1620    1.249001e-16
# private_edu_1620       -8.881784e-16
# first_married_1620     -5.551115e-17
# non_single_1620        -2.081668e-17
# happiness_1620          1.000000e+00
# dtype: float64

# %%
fig=plot_partregress_grid(model_1620)
fig.tight_layout(pad=1)
